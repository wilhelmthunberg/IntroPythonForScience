# %%
import numpy as np 
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import scipy.constants as const


#Q1
times = (0, 2e-7)# Time range
ttt = np.linspace(0, 2e-7, 10000) 
E= 1.6022e-16
m =1.673e-27
y= [0,0,0, np.sqrt(2*E/m),0,0]
B= [0,0,3]

def func_q1(t,y): 
    """ 
    Function to be used in ODE-solver 
    Input: t - Initial time[seconds]
           y - Initial position and velocity
           m - Mass of particle [eV]
           B - Vector for magnetic field [T]
    Output: z - vector containing velocity [:3] and accelerataion [3:]
    """
    y=np.array(y)
    z= np.zeros(6)
    z[:3] = y[3:]
    E= (y[3:]**2)*m*0.5
    z[3:] = (const.e *(E + np.cross(y[3:],B) ))/m
    return z

motion = solve_ivp(func_q1, times, y, t_eval=ttt)
plt.figure()
plt.plot(motion.t, motion.y[0])
plt.xlabel('Time[seconds]')
plt.ylabel('x- postion[m]')
plt.title('x-postion as a function of time')


plt.figure()
plt.plot(motion.t, motion.y[1])
plt.xlabel('Time[seconds]')
plt.ylabel('y- postion[m]')
plt.title('y-postion as a function of time')

plt.figure()
plt.plot(motion.t, motion.y[3])
plt.plot(motion.t, motion.y[4])
plt.xlabel('Time[seconds]')
plt.ylabel('velocity [m/s]')
plt.legend(['v_x', 'v_y'])
plt.title('x- and y-velocity as a function of time')

plt.figure()
plt.plot(motion.y[0], motion.y[1])
plt.xlabel('x-position[m]')
plt.ylabel('y- postion[m]')
plt.title('y-postion as a function of x')
# Out:
# Text(0.5, 1.0, 'y-postion as a function of x')

# %%
#Q2
#same input param except energy
times = (0, 2e-7)# Time range
ttt = np.linspace(0, 2e-7, 10000) 
E= 1.6022e-16
m =1.673e-27
y= [0,0,0, np.sqrt(E/m),0,np.sqrt(E/m)]#add
B= [0,0,3] 


motion = solve_ivp(func_q1, times, y, t_eval=ttt)
plt.figure()
plt.plot(motion.t, motion.y[0])
plt.xlabel('Time[seconds]')
plt.ylabel('x- postion[m]')
plt.title('x-postion as a function of time')


plt.figure()
plt.plot(motion.t, motion.y[0])
plt.plot(motion.t, motion.y[1])
plt.xlabel('Time[seconds]')
plt.ylabel('position [m]')
plt.legend(['x', 'y'])
plt.title('x- and y-position as a function of time')


plt.figure()
plt.plot(motion.t, motion.y[3])
plt.plot(motion.t, motion.y[4])
plt.plot(motion.t, motion.y[5])
plt.xlabel('Time[seconds]')
plt.ylabel('velocity [m/s]')
plt.legend(['v_x', 'v_y','v_z'])
plt.title('x- ,y- and z-velocity as a function of time')

plt.figure()
plt.plot(motion.y[0], motion.y[2])
plt.xlabel('x-position[m]')
plt.ylabel('z- postion[m]')
plt.title('z-postion as a function of x')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-034137b2c043> in <module>
#       5 E= 1.6022e-16
#       6 m =1.673e-27
# ----> 7 y= [sqrt(1.5),sqrt(1.5),0,0,0,np.sqrt(E/m)]#add
#       8 B= [0,0,3]
#       9
#
# NameError: name 'sqrt' is not defined

# %%
#Q3
def magnetic_field(x,y):
    """
    Function to calculate magnetic field strength at given x- and y-coordinates.
    
    Input: x and y coordinates
           x-float,int
           y-float,int
    Output: 3D np.array with the magnetic field
    """
    if x==0 and y==0:
        return np.zeros(3)
    else:
        B_strength = 9/(np.sqrt(x**2+y**2))
        B = B_strength* np.array([-y/(np.sqrt(x**2+y**2)),x/(np.sqrt(x**2+y**2)),0])
        return B
    
def func_q3(t,y): 
    """ 
    Function to be used in ODE-solver 
    Input: t - Initial time[seconds]
           y - Initial position and velocity
    Output: z - vector containing velocity [:3] and accelerataion [3:]
    """
    y=np.array(y)
    z= np.zeros(6)
    z[:3] = y[3:]
    E= (y[3:]**2)*m*0.5
    z[3:] = (const.e *(E + np.cross(y[3:],magnetic_field(y[0], y[1])) ))/m
  
    return z

times = (0, 2e-7)# Time range
ttt = np.linspace(0, 2e-7, 10000) 
E= 1.6022e-16
m =1.673e-27
y= [np.sqrt(1.5),np.sqrt(1.5),0, 0,0,np.sqrt(2*E/m)]#add

motion = solve_ivp(func_q3, times, y, t_eval=ttt)
plt.figure()
plt.plot(motion.t, motion.y[0])
plt.xlabel('Time[seconds]')
plt.ylabel('x- postion[m]')
plt.title('x-postion as a function of time')


plt.figure()
plt.plot(motion.t, motion.y[0])
plt.plot(motion.t, motion.y[1])
plt.xlabel('Time[seconds]')
plt.ylabel('position [m]')
plt.legend(['x', 'y'])
plt.title('x- and y-position as a function of time')


plt.figure()
plt.plot(motion.t, motion.y[3])
plt.plot(motion.t, motion.y[4])
plt.plot(motion.t, motion.y[5])
plt.xlabel('Time[seconds]')
plt.ylabel('velocity [m/s]')
plt.legend(['v_x', 'v_y','v_z'])
plt.title('x- ,y- and z-velocity as a function of time')

plt.figure()
plt.plot(motion.y[0], motion.y[2])
plt.xlabel('x-position[m]')
plt.ylabel('z- postion[m]')
plt.title('z-postion as a function of x')
# Out:
# <ipython-input-32-0bafdf79cb11>:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   B = B_strength* np.array([-y/(np.sqrt(x**2+y**2)),x/(np.sqrt(x**2+y**2)),0])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-0bafdf79cb11> in <module>
#      44 y= [np.sqrt(1.5),np.sqrt(1.5),0, 0,0,np.sqrt(2*E/m)]#add
#      45
# ---> 46 motion = solve_ivp(func_q3, times, y, t_eval=ttt)
#      47 plt.figure()
#      48 plt.plot(motion.t, motion.y[0])
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     540         method = METHODS[method]
#     541
# --> 542     solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     543
#     544     if t_eval is None:
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/rk.py in __init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      92         self.max_step = validate_max_step(max_step)
#      93         self.rtol, self.atol = validate_tol(rtol, atol, self.n)
# ---> 94         self.f = self.fun(self.t, self.y)
#      95         if first_step is None:
#      96             self.h_abs = select_initial_step(
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun(t, y)
#     136         def fun(t, y):
#     137             self.nfev += 1
# --> 138             return self.fun_single(t, y)
#     139
#     140         self.fun = fun
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun_wrapped(t, y)
#      18
#      19     def fun_wrapped(t, y):
# ---> 20         return np.asarray(fun(t, y), dtype=dtype)
#      21
#      22     return fun_wrapped, y0
#
# <ipython-input-32-0bafdf79cb11> in func_q3(t, y)
#      27     else:
#      28         B_strength = 9/(np.sqrt(x**2+y**2))
# ---> 29         B = B_strength* np.array([-y/(np.sqrt(x**2+y**2)),x/(np.sqrt(x**2+y**2)),0])
#      30
#      31
#
# ValueError: operands could not be broadcast together with shapes (6,) (3,)

# %%
x=1
y=1

magnetic_field(x,y)
# Out:
# array([-4.5,  4.5,  0. ])

# %%
9/(np.sqrt(x^2+y^2))
# Out:
# <ipython-input-22-c88737ab12ce>:1: RuntimeWarning: divide by zero encountered in double_scalars
#   9/(np.sqrt(x^2+y^2))
# inf

# %%
np.sqrt(x^2+y^2)
# Out:
# 0.0
